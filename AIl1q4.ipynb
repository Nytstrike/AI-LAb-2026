# %%
while(1):
  print("1. Addition")
  print("2. Subtraction")
  print("3. Exit")
  num = input("Enter a choice: ")
  num = int(num)
  if(num == 3):
    break
  elif(num == 2):
    x = input("Enter first number: ")
    y = input("Enter second number: ")
    x = int(x)
    y = int(y)
    print("result :", x-y)
  elif(num == 1):
     x = input("Enter first number: ")
     y = input("Enter second number: ")
     x = int(x)
     y = int(y)
     print("result :", x+y)
