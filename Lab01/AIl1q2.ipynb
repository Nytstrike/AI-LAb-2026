# %%
num = input("Enter a number: ")
num = int(num)
count = 0
for i in range(2,num):
    if(i % 2 == 0):
        print(i)
        count += 1
print("Total even numbers: ", count)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 num = input("Enter a number: ")
#       2 num = int(num)
#       3 for i in range(num):
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\ipykernel\kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
# ...
