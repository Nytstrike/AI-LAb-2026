# %%
records = {}
for i in range(0,3):
  name= input("Enter name: ")
  marks = input("Enter marks: ")
  records[name] = marks
for keys, values in records.items():
    print(f"{keys} : {values}")
# Out:
# Muhammad : 67
# Hasan : 90
